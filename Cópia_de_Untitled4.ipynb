# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroBetim/Motocross/blob/main/C%C3%B3pia_de_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##AVALIAÇÃO - QUESTIONÁRIO COLAB/PYTHON PROFESSOR NORI P.C.ATIVIDADE 1

# %%
nome = input ("Digite seu nome:")
print (f"Olá, {nome}! Qual é sua dúvida, caro estudande?")
resposta = input("Escolha um assunto: Inglês, Matemática, História, Portugês? ").strip().lower()
if resposta == "inglês":
    print("Tranquilo, vamos falar sobre inglês! Essa língua é muito importante!")
elif resposta == "matemática":
    print("Vamos resolver algumas questões então!")
elif resposta == "história":
  print("Quer saber algo histórico!")
elif resposta == "portugês":

# %% [markdown]
# ##ATIVIDADE AVALIATIVA

# %%
nome = input ("Digite seu nome")
print (f"Olá, {nome}! Oque você quer saber Estudante?")
resposta = input("Escolha um assunto entre: Esporte, Culinária, Futebol, Profissões, Atualidade?").strip().lower()
if resposta == "esporte":
  print("O esporte é um fenômeno global que vai além da atividade física, influenciando a cultura, a saúde e a sociedade.")
elif resposta == "culinária"
  print("É uma arte que combina habilidades técnicas, criatividade e conhecimento para criar pratos incríveis e satisfatórios.")
elif resposta == "futebol"
  print("O futebol é o esporte coletivo mais popular do planeta.")
  elif resposta == "profissões"
  print("É o trabalho especializado que exige formação específica (como médico ou engenheiro), enquanto a carreira é a jornada profissional ao longo do tempo, que pode envolver várias experiências e mudanças.")
  elif resposta == "atualidade"
  print("São os assuntos que estão em evidência nos últimos tempos, seja no Brasil, seja no exterior.")
# Out:
#   File "/tmp/ipython-input-4225735369.py", line 6
#     elif resposta == "culinária"
#                                 ^
# SyntaxError: expected ':'

# %%
nome = input ("Digite seu nome")
print (f"Olá, {nome}! Oque você quer saber Estudante?")
resposta = input("Escolha um assunto entre: Esporte, Culinária, Futebol, Profissões, Atualidade?").strip().lower()
if resposta == "esporte":
  print("O esporte é um fenômeno global que vai além da atividade física, influenciando a cultura, a saúde e a sociedade.")
elif resposta == "culinária":
  print("É uma arte que combina habilidades técnicas, criatividade e conhecimento para criar pratos incríveis e satisfatórios.")
elif resposta == "futebol":
  print("O futebol é o esporte coletivo mais popular do planeta.")
elif resposta == "profissões":
  print("É o trabalho especializado que exige formação específica (como médico ou engenheiro), enquanto a carreira é a jornada profissional ao longo do tempo, que pode envolver várias experiências e mudanças.")
elif resposta == "atualidade":
  print("São os assuntos que estão em evidência nos últimos tempos, seja no Brasil, seja no exterior.")
